# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# (Tip: make your own list of common pieces of code and syntax so you can easily refer to it, like a cheat sheet.)
#
# Introduction to basics:
#
# https://melaniewalsh.github.io/Intro-Cultural-Analytics/03-Data-Analysis/01-Pandas-Basics-Part1.html
#
# Official documentation:
#
# https://pandas.pydata.org/docs/reference/index.html
#
# Another reference:
#
# https://www.w3schools.com/python/pandas/pandas_ref_dataframe.asp

# %% [markdown]
# ## Creating a variable for a file as a dataframe

# %% [markdown]
# The two pieces of code below each have an error.

# %%
checkouts_df = read_csv('seattle_checkouts.tsv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 checkouts_df = read_csv('seattle_checkouts.tsv')
#
# NameError: name 'read_csv' is not defined

# %%
checkouts_df = pd.read_csv('seattle_checkouts.tsv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 checkouts_df = pd.read_csv('seattle_checkouts.tsv')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seattle_checkouts.tsv'

# %%
checkouts_df = pd.read_csv('seattle_checkouts.csv')

# %% [markdown]
# ## Selecting Columns

# %%
checkouts_df
# Out:
#       UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 0        Digital    OverDrive        EBOOK          2020              4
# 1        Digital    OverDrive        EBOOK          2020              4
# 2        Digital    OverDrive    AUDIOBOOK          2020              4
# 3        Digital    OverDrive        EBOOK          2020              4
# 4        Digital    OverDrive        EBOOK          2020              4
# ...          ...          ...          ...           ...            ...
# 93666    Digital    OverDrive        EBOOK          2020              4
# 93667    Digital    OverDrive    AUDIOBOOK          2020              4
# 93668    Digital    OverDrive        EBOOK          2020              4
# 93669    Digital    OverDrive    AUDIOBOOK          2020              4
# 93670    Digital    OverDrive        EBOOK          2020              4
#
#        Checkouts                                              Title  \
# 0              2                                 Nighttime Symphony
# 1              2                                          Cold Kill
# 2              1                            The Choice (Unabridged)
# 3              3                              The Master Key System
# 4             12                                  The Doughnut King
# ...          ...                                                ...
# 93666          4  The Black Moth: Historical Romances Series, Bo...
# 93667          1                 A Death in the Family (Unabridged)
# 93668          2                 My Fate According to the Butterfly
# 93669         17  The Second Sleep: A novel (unabridged) (Unabri...
# 93670          3  A Dilly of a Death: China Bayles Mystery Serie...
#
#                    Creator                                          Subjects  \
# 0                Timbaland            Juvenile Fiction, Picture Book Fiction
# 1             Rennie Airth                        Fiction, Mystery, Thriller
# 2          Nicholas Sparks                               Fiction, Literature
# 3        Charles F. Haanel             New Age, Nonfiction, Self-Improvement
# 4          Jessie Janowitz             Juvenile Fiction, Juvenile Literature
# ...                    ...                                               ...
# 93666      Georgette Heyer  Fiction, Historical Fiction, Literature, Romance
# 93667           James Agee                       Classic Literature, Fiction
# 93668      Gail Villanueva             Juvenile Fiction, Juvenile Literature
# 93669        Robert Harris                       Fiction, Suspense, Thriller
# 93670  Susan Wittig Albert                                  Fiction, Mystery
#
#                          Publisher PublicationYear
# 0           Simon & Schuster, Inc.            2019
# 1      Severn House Publishers Ltd            2020
# 2                    Books on Tape            2007
# 3                    Duke Classics            2020
# 4                      Sourcebooks            2019
# ...                            ...             ...
# 93666                  Sourcebooks            2010
# 93667       Blackstone Audio, Inc.            2012
# 93668        Scholastic, Inc. (US)            2019
# 93669                Books on Tape            2019
# 93670    Penguin Group (USA), Inc.            2011
#
# [93671 rows x 11 columns]

# %% [markdown]
# Correct the error below.

# %%
checkouts_df[["Checkouts", "Creator"]]
# Out:
#        Checkouts              Creator
# 0              2            Timbaland
# 1              2         Rennie Airth
# 2              1      Nicholas Sparks
# 3              3    Charles F. Haanel
# 4             12      Jessie Janowitz
# ...          ...                  ...
# 93666          4      Georgette Heyer
# 93667          1           James Agee
# 93668          2      Gail Villanueva
# 93669         17        Robert Harris
# 93670          3  Susan Wittig Albert
#
# [93671 rows x 2 columns]

# %% [markdown]
# ## Counting values in a dataframe

# %% [markdown]
# Modify the line below to find the 10 most common publication years among the items checked out.

# %%
nyt_df['title'].value_counts()

# %% [markdown]
# ## Using `.describe()`

# %% [markdown]
# Try to interpret what each of the rows in the table means.

# %%
checkouts_df.describe(include="all")

# %% [markdown]
# How does the output differ when using different parameters?

# %%
checkouts_df[:10]

# %%
checkouts_df.describe(include="object")

# %%
checkouts_df.describe(include="int64")

# %%
# What if I try this?
checkouts_df.describe(include="Creator")

# %% [markdown]
# ### Data types in Pandas

# %% [markdown]
# | Python         | Pandas             |
# |----------------|--------------------|
# |String (`str`)  | Object (`object`)  |
# |Integer (`int`) | Int64 (`int64`)    |
# |Float (`float`) | Float64 (`float64`)|
# |List (`list`)   |$\approx$ Series (`Series`)   |
# |                |DataFrames (`DataFrame`)|

# %% [markdown]
# ## Filtering data

# %% [markdown]
# Modify the line below to get a data frame containing only the entries with books by Geronimo Stilton and store the result in a variable called `stilton_df`

# %%
stilton_df = checkouts_df[checkouts_df['Creator'] == 'Geronimo Stilton']

# %%
stilton_df
# Out:
#       UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 884      Digital    OverDrive        EBOOK          2020              4
# 1002     Digital    OverDrive        EBOOK          2020              4
# 1741     Digital    OverDrive        EBOOK          2020              4
# 2371     Digital    OverDrive        EBOOK          2020              4
# 3822     Digital    OverDrive        EBOOK          2020              4
# ...          ...          ...          ...           ...            ...
# 91589    Digital    OverDrive        EBOOK          2020              4
# 92440    Digital    OverDrive        EBOOK          2020              4
# 93235    Digital    OverDrive        EBOOK          2020              4
# 93471    Digital    OverDrive        EBOOK          2020              4
# 93635    Digital    OverDrive        EBOOK          2020              4
#
#        Checkouts                                              Title  \
# 884            6  Rumble in the Jungle: Geronimo Stilton Series,...
# 1002           1  Stay Strong, Geronimo!: Geronimo Stilton Micek...
# 1741           1  Run for the Hills, Geronimo!: Geronimo Stilton...
# 2371           3  Geronimo Stilton Saves the Olympics: Geronimo ...
# 3822           2  The Race Against Time: Geronimo Stilton Journe...
# ...          ...                                                ...
# 91589          4  The Mysterious Message: Geronimo Stilton Micek...
# 92440          6  The Missing Movie: Geronimo Stilton Series, Bo...
# 93235          3  Rescue Rebellion: Geronimo Stilton Spacemice S...
# 93471          2  Wedding Crasher: Geronimo Stilton Series, Book 28
# 93635          2  A Fabumouse School Adventure: Geronimo Stilton...
#
#                 Creator                                           Subjects  \
# 884    Geronimo Stilton              Juvenile Fiction, Juvenile Literature
# 1002   Geronimo Stilton  Humor (Fiction), Juvenile Fiction, Juvenile Li...
# 1741   Geronimo Stilton              Juvenile Fiction, Juvenile Literature
# 2371   Geronimo Stilton          Comic and Graphic Books, Juvenile Fiction
# 3822   Geronimo Stilton                  Humor (Fiction), Juvenile Fiction
# ...                 ...                                                ...
# 91589  Geronimo Stilton  Humor (Fiction), Juvenile Fiction, Juvenile Li...
# 92440  Geronimo Stilton  Humor (Fiction), Juvenile Fiction, Juvenile Li...
# 93235  Geronimo Stilton                  Humor (Fiction), Juvenile Fiction
# 93471  Geronimo Stilton              Juvenile Fiction, Juvenile Literature
# 93635  Geronimo Stilton              Juvenile Fiction, Juvenile Literature
#
#                    Publisher PublicationYear
# 884    Scholastic, Inc. (US)            2015
# 1002   Scholastic, Inc. (US)            2017
# 1741   Scholastic, Inc. (US)            2015
# 2371    Macmillan Publishers            2015
# 3822   Scholastic, Inc. (US)            2016
# ...                      ...             ...
# 91589  Scholastic, Inc. (US)            2017
# 92440  Scholastic, Inc. (US)            2019
# 93235  Scholastic, Inc. (US)            2015
# 93471  Scholastic, Inc. (US)            2015
# 93635  Scholastic, Inc. (US)            2015
#
# [172 rows x 11 columns]
