# %% [markdown]
# ## The ``merge`` function
# Let's experiment with the ``merge`` function.

# %%
import pandas as pd
fruit_data = [["apple", 5, "red"], ["banana", 6, "yellow"], ["blueberry", 9, "blue"], ["mango", 5, "orange"]]
fruits_df = pd.DataFrame(fruit_data, columns=["Name", "Name length", "Colour"])
fruits_df
# Out:
#         Name  Name length  Colour
# 0      apple            5     red
# 1     banana            6  yellow
# 2  blueberry            9    blue
# 3      mango            5  orange

# %%
fruits_alt_data = [["apple", "green"], ["banana", "brown"], ["blueberry", "purple"], ["mango", "green"]]
fruits_alt_df = pd.DataFrame(fruits_alt_data, columns = ["Name", "Alt Colour"])
fruits_alt_df
# Out:
#         Name Alt Colour
# 0      apple      green
# 1     banana      brown
# 2  blueberry     purple
# 3      mango      green

# %%
fruits_merged_df = pd.merge(fruits_df, fruits_alt_df, on="Name")
fruits_merged_df
# Out:
#         Name  Name length  Colour Alt Colour
# 0      apple            5     red      green
# 1     banana            6  yellow      brown
# 2  blueberry            9    blue     purple
# 3      mango            5  orange      green

# %% [markdown]
# What happens if we add extra rows??

# %%
fruits_alt_data = [["apple", "green"], ["banana", "brown"], ["blueberry", "purple"],
                   ["mango", "green"],["avocado", "brown"], ["grape", "green"]]
                   
fruits_alt_df = pd.DataFrame(fruits_alt_data, columns = ["Name", "Alt Colour"])
fruits_alt_df
# Out:
#         Name Alt Colour
# 0      apple      green
# 1     banana      brown
# 2  blueberry     purple
# 3      mango      green
# 4    avocado      brown
# 5      grape      green

# %%
fruits_merged_df = pd.merge(fruits_df, fruits_alt_df, on="Name")
fruits_merged_df
# Out:
#         Name  Name length  Colour Alt Colour
# 0      apple            5     red      green
# 1     banana            6  yellow      brown
# 2  blueberry            9    blue     purple
# 3      mango            5  orange      green

# %% [markdown]
# What happened to the extra rows that were added?

# %% [markdown]
# If we check the [pandas documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html), we see that we can input extra parameters, such as the "how" argument. Try them to see how they work!

# %%
fruits_merged_df = pd.merge(fruits_df, fruits_alt_df, on="Name", how="outer")
fruits_merged_df

# %%
fruits_merged_df = pd.merge(fruits_df, fruits_alt_df, how="cross")
fruits_merged_df

# %% [markdown]
# ## The ``.groupby()`` method
# Now let's work with a real example.

# %%
import pandas as pd

checkouts_df = pd.read_csv('seattle_checkouts.csv')
checkouts_df
# Out:
#       UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 0        Digital    OverDrive        EBOOK          2020              4
# 1        Digital    OverDrive        EBOOK          2020              4
# 2        Digital    OverDrive    AUDIOBOOK          2020              4
# 3        Digital    OverDrive        EBOOK          2020              4
# 4        Digital    OverDrive        EBOOK          2020              4
# ...          ...          ...          ...           ...            ...
# 93666    Digital    OverDrive        EBOOK          2020              4
# 93667    Digital    OverDrive    AUDIOBOOK          2020              4
# 93668    Digital    OverDrive        EBOOK          2020              4
# 93669    Digital    OverDrive    AUDIOBOOK          2020              4
# 93670    Digital    OverDrive        EBOOK          2020              4
#
#        Checkouts                                              Title  \
# 0              2                                 Nighttime Symphony
# 1              2                                          Cold Kill
# 2              1                            The Choice (Unabridged)
# 3              3                              The Master Key System
# 4             12                                  The Doughnut King
# ...          ...                                                ...
# 93666          4  The Black Moth: Historical Romances Series, Bo...
# 93667          1                 A Death in the Family (Unabridged)
# 93668          2                 My Fate According to the Butterfly
# 93669         17  The Second Sleep: A novel (unabridged) (Unabri...
# 93670          3  A Dilly of a Death: China Bayles Mystery Serie...
#
#                    Creator                                          Subjects  \
# 0                Timbaland            Juvenile Fiction, Picture Book Fiction
# 1             Rennie Airth                        Fiction, Mystery, Thriller
# 2          Nicholas Sparks                               Fiction, Literature
# 3        Charles F. Haanel             New Age, Nonfiction, Self-Improvement
# 4          Jessie Janowitz             Juvenile Fiction, Juvenile Literature
# ...                    ...                                               ...
# 93666      Georgette Heyer  Fiction, Historical Fiction, Literature, Romance
# 93667           James Agee                       Classic Literature, Fiction
# 93668      Gail Villanueva             Juvenile Fiction, Juvenile Literature
# 93669        Robert Harris                       Fiction, Suspense, Thriller
# 93670  Susan Wittig Albert                                  Fiction, Mystery
#
#                          Publisher PublicationYear
# 0           Simon & Schuster, Inc.            2019
# 1      Severn House Publishers Ltd            2020
# 2                    Books on Tape            2007
# 3                    Duke Classics            2020
# 4                      Sourcebooks            2019
# ...                            ...             ...
# 93666                  Sourcebooks            2010
# 93667       Blackstone Audio, Inc.            2012
# 93668        Scholastic, Inc. (US)            2019
# 93669                Books on Tape            2019
# 93670    Penguin Group (USA), Inc.            2011
#
# [93671 rows x 11 columns]

# %% [markdown]
# Let's try to find the creators whose works were checked out the most in April 2020.

# %%
#Why does this not accurately portray the creators whose works were checked out the most?
checkouts_df['Creator'].value_counts()[:20]
# Out:
# James Patterson              370
# Daisy Meadows                219
# Agatha Christie              211
# Gertrude  Chandler Warner    174
# Geronimo Stilton             172
# Mary Pope Osborne            170
# Stephen King                 168
# Louis L'Amour                167
# Nora Roberts                 158
# Erin Hunter                  152
# Dan Gutman                   147
# M. C. Beaton                 144
# Stuart Woods                 144
# Stan Berenstain              136
# DK                           131
# Robert B. Parker             120
# Janet Evanovich              116
# Clive Cussler                116
# J. A. Jance                  112
# Debbie Macomber              111
# Name: Creator, dtype: int64

# %% [markdown]
# We can use the ``.groupby()`` and ``.sum()`` method

# %%
checkouts_grouped_summed_df = checkouts_df.groupby(['Creator']).sum(numeric_only=True)
checkouts_grouped_summed_df[:20]
# Out:
#                   CheckoutYear  CheckoutMonth  Checkouts
# Creator
# (法)凡尔纳                    2020              4          1
# 50 Cent                   6060             12          4
# A'Lelia Bundles           4040              8         10
# A. A. Aguirre             2020              4          1
# A. A. Milne              26260             52         48
# A. Alpheus                2020              4          1
# A. B. Greenfield          2020              4          1
# A. B. Jewell              2020              4          4
# A. Birnbaum               2020              4          1
# A. C. Gaughen             4040              8          3
# A. C. Grayling            4040              8          7
# A. C. Weisbecker          2020              4          1
# A. Cantab                 2020              4          6
# A. Conan Doyle            2020              4          1
# A. D. Miller              2020              4          2
# A. D. Robertson           2020              4          2
# A. E. Dingee              2020              4          1
# A. E. Hotchner            4040              8          3
# A. E. W. Mason            8080             16          7
# A. G. Howard             12120             24         11

# %%
checkouts_grouped_summed_df[["Checkouts"]].nlargest(10, columns="Checkouts")
# Out:
#                   Checkouts
# Creator
# J. K. Rowling          3877
# James Patterson        1711
# David Baldacci         1449
# Michael Connelly       1367
# Agatha Christie        1362
# Stephen King           1271
# Lee Child              1264
# John Grisham           1154
# Kevin Kwan             1153
# Michelle Obama         1098

# %% [markdown]
# Make a chart!

# %%
checkouts_grouped_summed_df[["Checkouts"]].nlargest(20, columns="Checkouts").plot(kind='bar', figsize=(10, 5), title='10 Most Checked-Out Creators', color ="orchid")
# Out:
# <AxesSubplot: title={'center': '10 Most Checked-Out Creators'}, xlabel='Creator'>

# %% [markdown]
# ## Grouping multiple columns

# %% [markdown]
# We can also try to compare statistics for different periods of time.

# %% [markdown]
# ``seattle_checkouts_2020.csv`` contains all the checkout data over 2020.

# %%
import pandas as pd
checkouts2020_df = pd.read_csv('seattle_checkouts_2020.csv')

# %%
checkouts2020_df
# Out:
#         UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 0         Physical      Horizon         BOOK          2020              8
# 1          Digital    OverDrive        EBOOK          2020              8
# 2          Digital    OverDrive        EBOOK          2020              8
# 3          Digital    OverDrive        EBOOK          2020              8
# 4          Digital    OverDrive        EBOOK          2020              8
# ...            ...          ...          ...           ...            ...
# 1721371    Digital    OverDrive        EBOOK          2020             12
# 1721372   Physical      Horizon         BOOK          2020             12
# 1721373   Physical      Horizon         BOOK          2020             12
# 1721374   Physical      Horizon         BOOK          2020             12
# 1721375   Physical      Horizon    VIDEODISC          2020             12
#
#          Checkouts                                              Title  ISBN  \
# 0                1                              Harvest / Sam Inglis.   NaN
# 1                1                                      The Race Beat   NaN
# 2                5                                   I Can Cook Vegan   NaN
# 3                1                              Follow the Stars Home   NaN
# 4                1                                 Blood of Innocence   NaN
# ...            ...                                                ...   ...
# 1721371          4                                Blueberries for Sal   NaN
# 1721372          1                          Squad / Mariah MacCarthy.   NaN
# 1721373          2  Out of this world : poems and facts about spac...   NaN
# 1721374          5  Ring shout : or, Hunting Ku Kluxes in the end ...   NaN
# 1721375          1  They call us monsters / a New Artists Alliance...   NaN
#
#                        Creator  \
# 0                  Inglis, Sam
# 1                 Gene Roberts
# 2        Isa Chandra Moskowitz
# 3                  Luanne Rice
# 4                    Tami Dane
# ...                        ...
# 1721371       Robert McCloskey
# 1721372      MacCarthy, Mariah
# 1721373       Sklansky, Amy E.
# 1721374        Clark, P. Djèlí
# 1721375                    NaN
#
#                                                   Subjects  \
# 0                                  Young Neil 1945 Harvest
# 1                 History, Nonfiction, Politics, Sociology
# 2                               Cooking & Food, Nonfiction
# 3                                         Fiction, Romance
# 4                                Fantasy, Fiction, Romance
# ...                                                    ...
# 1721371  Juvenile Fiction, Juvenile Literature, Picture...
# 1721372  Cheerleading Juvenile fiction, Best friends Ju...
# 1721373  Outer space Juvenile poetry, Outer space Juven...
# 1721374  Ku Klux Klan 1915 Fiction, African Americans G...
# 1721375  Sylmar Juvenile Hall Sylmar Calif, Juvenile de...
#
#                          Publisher PublicationYear
# 0                       Continuum,           2003.
# 1               Random House, Inc.            2008
# 2                           ABRAMS            2019
# 3               Random House, Inc.            2012
# 4             Lightning Source Inc            2012
# ...                            ...             ...
# 1721371  Penguin Group (USA), Inc.            2014
# 1721372      Farrar Straus Giroux,           2019.
# 1721373           Alfred A. Knopf,          [2012]
# 1721374                 Tordotcom,           2020.
# 1721375               The Orchard,          c2016.
#
# [1721376 rows x 12 columns]

# %%
checkouts2020_df.groupby(["CheckoutMonth", "MaterialType"])

# %%
checkouts2020_df.groupby(["CheckoutMonth", "MaterialType"]).size()
# Out:
# CheckoutMonth  MaterialType
# 1              ATLAS               13
#                AUDIOBOOK        25307
#                BOOK            103645
#                CR                  89
#                EBOOK            55642
#                                 ...
# 12             UNSPECIFIED          3
#                VIDEO               95
#                VIDEODISC        10057
#                VIDEOREC             1
#                VISUAL               7
# Length: 264, dtype: int64

# %%
checkouts2020_df.groupby(["CheckoutMonth", "MaterialType"]).size().unstack(fill_value=0)
# Out:
# MaterialType   ATLAS  AUDIOBOOK    BOOK  CR  EBOOK  ER  ER, NONPROJGRAPH  \
# CheckoutMonth
# 1                 13      25307  103645  89  55642  67                 1
# 2                 19      25202  100713  71  54846  64                 1
# 3                 17      25559   84689  51  62678  42                 1
# 4                  0      25810      66   0  67548   0                 0
# 5                  0      26588      87   0  68724   0                 0
# 6                  0      26198      42   0  67079   0                 0
# 7                  0      27381      50   0  67741   0                 0
# 8                  0      27377    6579   2  67137   5                 0
# 9                  9      26958   35899  10  66292  20                 0
# 10                 8      26674   44669  15  64839  27                 0
# 11                 5      26702   42921  12  64627  25                 1
# 12                 5      27446   48236  18  65233  24                 0
#
# MaterialType   ER, PRINT  ER, SOUNDDISC  ER, VIDEODISC  ...  \
# CheckoutMonth                                           ...
# 1                      0             31             25  ...
# 2                      1             46             21  ...
# 3                      1             34             17  ...
# 4                      0              0              0  ...
# 5                      0              0              0  ...
# 6                      0              0              0  ...
# 7                      0              0              0  ...
# 8                      0              2              3  ...
# 9                      1             16             10  ...
# 10                     0              9              5  ...
# 11                     0              7              6  ...
# 12                     0              7             10  ...
#
# MaterialType   SOUNDDISC, VIDEOCASS  SOUNDDISC, VIDEODISC  SOUNDREC  \
# CheckoutMonth
# 1                                 0                   145        83
# 2                                 0                   153        52
# 3                                 0                   103        64
# 4                                 0                     0         0
# 5                                 0                     0         0
# 6                                 0                     0         0
# 7                                 0                     0         0
# 8                                 0                    10         2
# 9                                 0                    41        20
# 10                                0                    59        33
# 11                                1                    54        18
# 12                                1                    87        29
#
# MaterialType   UNSPECIFIED  VIDEO  VIDEOCART  VIDEOCASS  VIDEODISC  VIDEOREC  \
# CheckoutMonth
# 1                        5    148          2          6      18888         1
# 2                        5    115          2          4      18837         1
# 3                        5    151          2          4      16375         1
# 4                        0    236          0          0          4         0
# 5                        0    177          0          0          3         0
# 6                        0    173          0          0          4         0
# 7                        0    135          0          0         12         0
# 8                        1    155          0          0       1994         0
# 9                        2    195          0          0       6389         1
# 10                       3    135          1          0       7654         1
# 11                       5    104          0          0       7953         1
# 12                       3     95          0          0      10057         1
#
# MaterialType   VISUAL
# CheckoutMonth
# 1                  10
# 2                   9
# 3                   7
# 4                   0
# 5                   0
# 6                   0
# 7                   0
# 8                   1
# 9                   3
# 10                  3
# 11                  2
# 12                  7
#
# [12 rows x 43 columns]

# %%
#Assign the data frame to a variable so we can work with it
checkout_types_per_month_df = checkouts2020_df.groupby(["CheckoutMonth", "MaterialType"]).size().unstack(fill_value=0)

# %%
#Isolate the most relevant columns
checkout_types_per_month_df[["AUDIOBOOK", "BOOK", "EBOOK", "VIDEO", "VIDEODISC"]]
# Out:
# MaterialType   AUDIOBOOK    BOOK  EBOOK  VIDEO  VIDEODISC
# CheckoutMonth
# 1                  25307  103645  55642    148      18888
# 2                  25202  100713  54846    115      18837
# 3                  25559   84689  62678    151      16375
# 4                  25810      66  67548    236          4
# 5                  26588      87  68724    177          3
# 6                  26198      42  67079    173          4
# 7                  27381      50  67741    135         12
# 8                  27377    6579  67137    155       1994
# 9                  26958   35899  66292    195       6389
# 10                 26674   44669  64839    135       7654
# 11                 26702   42921  64627    104       7953
# 12                 27446   48236  65233     95      10057

# %%
#Make a chart!
checkout_types_per_month_df[["AUDIOBOOK", "BOOK", "EBOOK", "VIDEO", "VIDEODISC"]].plot(kind='bar', figsize=(10, 5), title='Checkouts', color=["honeydew", "pink", "darkgoldenrod", "slateblue", "mediumpurple"])
# Out:
# <AxesSubplot: title={'center': 'Checkouts'}, xlabel='CheckoutMonth'>

# %% [markdown]
# **Chart colours**
#
# In the above chart, we specified a *list* of colours to use with the extra parameter `color=["gainsboro", "pink", "darkgoldenrod", "slateblue", "mediumpurple"]`
#
# List of named colors:
# https://matplotlib.org/stable/gallery/color/named_colors.html
#
# You can also use hex codes, e.g. `'#fa8702'`
# https://htmlcolorcodes.com/
